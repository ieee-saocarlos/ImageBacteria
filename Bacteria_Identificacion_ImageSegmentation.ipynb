# %%
#!pip install tensorflow==2.6.0

# %%
from google.colab import files
from google_drive_downloader import GoogleDriveDownloader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch 
import os
import tqdm
import tensorflow as tf
import pandas as pd
import albumentations as A
import cv2
import torchvision
import glob
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
import torch.nn as nn
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %% [markdown]
# Preparing the dataset

# %%
images_path = Path('/content/drive/MyDrive/IA/IMG/bacteria/images')
masks_path = Path('/content/drive/MyDrive/IA/IMG/bacteria/masks')

images = list(images_path.glob(r'*.png')) # creates a list with every image
masks = list(masks_path.glob(r'*.png')) # creates a list with every mask
print(images)
images = pd.Series(images, name = 'images').sort_values() # converting the list into a Series object and using sort_values() to organize it in crescent order
masks = pd.Series(masks, name = 'masks').sort_values()

images.reset_index(drop = True, inplace = True) #reset the index because even after you sort the elements in a Series object the index will remain the same
masks.reset_index(drop = True, inplace = True)

dataset = pd.concat([images, masks], axis =1) #unifying masks and images in a unique Dataframe
# Out:
# [PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/003.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/001.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/002.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/008.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/006.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/016.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/017.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/011.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/019.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/012.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/013.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/020.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/015.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/014.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/004.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/007.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/010.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/005.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/009.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/018.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/039.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/026.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/022.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/024.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/031.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/028.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/027.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/032.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/033.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/025.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/038.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/030.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/023.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/029.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/034.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/021.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/037.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/035.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/036.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/050.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/079.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/072.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/047.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/041.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/070.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/078.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/053.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/083.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/077.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/069.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/084.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/074.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/044.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/063.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/043.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/064.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/081.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/images/051.png'), PosixPath('/content/drive/MyDrive/IA/IMG/bacteria/image ...

# %% [markdown]
# Suport reading function

# %%
def read(path):
  array = cv2.imread(str(path))
  array = cv2.cvtColor(array, cv2.COLOR_BGR2RGB)
  return array

# %% [markdown]
# Checking out our new Dataframe

# %%
dataset
# Out:
#                                                 images  \
# 0    /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 1    /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 2    /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 3    /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 4    /content/drive/MyDrive/IA/IMG/bacteria/images/...
# ..                                                 ...
# 361  /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 362  /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 363  /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 364  /content/drive/MyDrive/IA/IMG/bacteria/images/...
# 365  /content/drive/MyDrive/IA/IMG/bacteria/images/...
#
#                                                  masks
# 0    /content/drive/MyDrive/IA/IMG/bacteria/masks/0...
# 1    /content/drive/MyDrive/IA/IMG/bacteria/masks/0...
# 2    /content/drive/MyDrive/IA/IMG/bacteria/masks/0...
# 3    /content/drive/MyDrive/IA/IMG/bacteria/masks/0...
# 4    /content/drive/MyDrive/IA/IMG/bacteria/masks/0...
# ..                                                 ...
# 361  /content/drive/MyDrive/IA/IMG/bacteria/masks/3...
# 362  /content/drive/MyDrive/IA/IMG/bacteria/masks/3...
# 363  /content/drive/MyDrive/IA/IMG/bacteria/masks/3...
# 364  /content/drive/MyDrive/IA/IMG/bacteria/masks/3...
# 365  /content/drive/MyDrive/IA/IMG/bacteria/masks/3...
#
# [366 rows x 2 columns]

# %% [markdown]
# Checking the shape of the images

# %%
for i in range(10):
  print(read(dataset.images.iloc[i]).shape)
# Out:
# (720, 710, 3)
# (1076, 1406, 3)
# (1078, 1402, 3)
# (1080, 1020, 3)
# (1080, 848, 3)
# (1080, 880, 3)
# (1080, 880, 3)
# (1080, 924, 3)
# (1080, 1154, 3)
# (1070, 1066, 3)

# %% [markdown]
# Resizing images and masks

# %%
resized_imgs = []
resized_masks = []
for image, mask in zip(dataset.images, dataset.masks): #zip function creates a iterable object, to create a dic type: list(zip_object)
  image_resized = cv2.resize(read(image), (256,256))
  mask_resized = cv2.resize(read(mask), (256,256))

  resized_imgs.append(image_resized)
  resized_masks.append(mask_resized)
print(len(resized_imgs))
print(len(resized_masks))
# Out:
# 366
# 366

# %% [markdown]
# Taking only the mask that identify bacterias

# %%
#masks = np.array(resized_masks)
#new_masks = []
#for i in range(len(masks)):
#  new_mask = np.equal(masks[i],2)*1 #keeping only values equal to 2 in the image
#  new_masks.append(np.array(new_mask))  
#new_masks = np.array(new_masks)

# %% [markdown]
# Cropping images and masks

# %%
new_imgs_crop = []
new_masks_crop = []
for img,mask in zip(resized_imgs, resized_masks):
  for i in range(1,3):
    for j in range(1,3):
      init0 = 128*(i-1)
      end0 = 128*i
      init1 = 128*(j-1)
      end1 = 128*j
      new_img = img[init0:end0, init1:end1 ,:]
      new_mask = mask[init0:end0, init1:end1 ,:]
      new_imgs_crop.append(new_img)
      new_masks_crop.append(new_mask[:,:,0])
 
new_imgs_crop = np.array(new_imgs_crop)
new_masks_crop = np.array(new_masks_crop)

# %% [markdown]
# Exploring the masks

# %%
#print(np.unique(new_masks[5])) #how many diferent values there are in the image matrix
#print(masks[5].shape)
#print(new_masks[5].shape)
#plt.imshow(new_masks[5][:,:,0])

# %% [markdown]
# adding a dimension to masks so it fits in the CNN

# %%
print(new_imgs_crop.shape)
print(new_masks_crop.shape)
new_masks_crop = new_masks_crop.reshape((new_masks_crop.shape[0], new_masks_crop.shape[1], new_masks_crop.shape[2],1))
#new_imgs_crop = new_imgs_crop.reshape((new_imgs_crop.shape[0], new_imgs_crop.shape[1], new_imgs_crop.shape[2],1))
print(new_imgs_crop.shape)
print(new_masks_crop.shape)
# Out:
# (1464, 128, 128, 3)
# (1464, 128, 128)
# (1464, 128, 128, 3)
# (1464, 128, 128, 1)

# %% [markdown]
# separating the dataset into trainset and testset

# %%
size = new_imgs_crop.shape[0]
train_imgs = new_imgs_crop[:int(size*0.95)]
train_masks = new_masks_crop[:int(size*0.95)]

test_imgs = new_imgs_crop[int(size*0.95):]
test_masks = new_masks_crop[int(size*0.95):]

# %% [markdown]
# Checking the sets out

# %%
print(train_imgs.shape)
print(train_masks.shape)
print(test_imgs.shape)
print(test_masks.shape)
# Out:
# (1390, 128, 128, 3)
# (1390, 128, 128, 1)
# (74, 128, 128, 3)
# (74, 128, 128, 1)

# %% [markdown]
# changing the classes identification from 0,1,2 to [1,0,0], [0,1,0], [0,0,1]

# %%
from tensorflow.keras.utils import to_categorical
train_masks_categorical = to_categorical(train_masks, num_classes = 3)
test_masks_categorical = to_categorical(test_masks, num_classes = 3)

# %%
print(train_imgs.shape)
print(train_masks_categorical.shape)
print(test_imgs.shape)
print(test_masks_categorical.shape)
# Out:
# (1390, 128, 128, 3)
# (1390, 128, 128, 3)
# (74, 128, 128, 3)
# (74, 128, 128, 3)

# %%
from keras.models import Model
from keras import activations

# %%
print(train_masks[0].shape)
np.unique(train_masks[2])
# Out:
# (128, 128, 1)
# array([0, 1, 2], dtype=uint8)

# %% [markdown]
# preprocessing

# %%
layers = tf.keras.layers
model = tf.keras.models.Sequential()
  #encoder
def model(filters_number):  

  n = (3,3)
  input = layers.Input((128,128,3))
  l1 = layers.Rescaling(1./255)(input)
  l4 = layers.RandomContrast(0.4)(l1)
  #print(input)
  c1 = layers.Conv2D(filters_number, n, activation = 'relu',padding = 'same', input_shape = input.shape )(l4)
  print(c1)
  c1 = layers.Conv2D(filters_number, n,activation = 'relu',padding = 'same')(c1)
  print(c1)
  m1 = layers.MaxPooling2D(pool_size = (2,2))(c1)
  m1 = layers.Dropout(0.25)(m1)

  c2 = layers.Conv2D(filters_number*2, n, padding = 'same',activation = 'relu')(m1)
  print(c2)  
  c2 = layers.Conv2D(filters_number*2, n,padding = 'same', activation = 'relu')(c2)
  print(c2)
  m2 = layers.MaxPooling2D(pool_size = (2,2))(c2)
  m2 = layers.Dropout(0.5)(m2)

  c3 = layers.Conv2D(filters_number*4, n, padding = 'same',activation = 'relu')(m2)
  print(c3)
  c3 = layers.Conv2D(filters_number*4, n,padding = 'same', activation = 'relu')(c3)
  print(c3)
  m3 = layers.MaxPooling2D(pool_size = (2,2))(c3)
  m3 = layers.Dropout(0.5)(m3)

  c4 = layers.Conv2D(filters_number*8, n, padding = 'same',activation = 'relu')(m3)
  print(c4)
  c4 = layers.Conv2D(filters_number*8, n,padding = 'same', activation = 'relu')(c4)
  print(c4)
  m4 = layers.MaxPooling2D(pool_size = (2,2))(c4)
  m4 = layers.Dropout(0.5)(m4)

  c5 = layers.Conv2D(filters_number*16, n, padding = 'same',activation = 'relu')(m4)
  print(c5)
  c5 = layers.Conv2D(filters_number*16, n,padding = 'same', activation = 'relu')(c5)
  print(c5)

  d20 = layers.Conv2DTranspose(filters_number*8,n, strides=(2,2), padding = 'same', activation='relu')(c5)
  print(d20)
  u1 = layers.concatenate([d20, c4])
  u1 = layers.Dropout(0.5)(u1)
  c50 = layers.Conv2D(filters_number*8, n, padding = 'same',activation = 'relu')(u1)
  c60 = layers.Conv2D(filters_number*8, n,padding = 'same', activation = 'relu')(c50)
  #c70 = layers.Conv2D(filters_number*8, n,padding = 'same', activation = 'relu')(c60)

  d21 = layers.Conv2DTranspose(filters_number*4, n, strides=(2,2), padding = 'same', activation='relu')(c60)
  u2 = layers.concatenate([d21, c3])
  u2 = layers.Dropout(0.5)(u2)
  c70 = layers.Conv2D(filters_number*4, n, padding = 'same',activation = 'relu')(u2)
  c80 = layers.Conv2D(filters_number*4, n,padding = 'same', activation = 'relu')(c70)

  d22 = layers.Conv2DTranspose(filters_number*2,n, strides=(2,2), padding = 'same', activation='relu')(c80)
  u3 = layers.concatenate([d22, c2])
  u3 = layers.Dropout(0.5)(u3)
  c90 = layers.Conv2D(filters_number*2, n, padding = 'same',activation = 'relu')(u3)
  c100 = layers.Conv2D(filters_number*2, n,padding = 'same', activation = 'relu')(c90)

  d23 = layers.Conv2DTranspose(filters_number*1,n, strides=(2,2), padding = 'same', activation='relu')(c100)
  u4 = layers.concatenate([d23, c1])
  u4 = layers.Dropout(0.5)(u4)
  c110 = layers.Conv2D(filters_number*1, n, padding = 'same',activation = 'relu')(u4)
  c120 = layers.Conv2D(filters_number*1, n,padding = 'same', activation = 'relu')(c110)

  output = layers.Conv2D(3, n, padding = 'same', activation='softmax')(c120)

  return Model(inputs=input, outputs=output)
    #decoder

# %%
filters_number = 32
model = model(filters_number)
#model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='conv2d/Relu:0', description="created by layer 'conv2d'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 128, 128, 32), dtype=tf.float32, name=None), name='conv2d_1/Relu:0', description="created by layer 'conv2d_1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='conv2d_2/Relu:0', description="created by layer 'conv2d_2'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 64, 64), dtype=tf.float32, name=None), name='conv2d_3/Relu:0', description="created by layer 'conv2d_3'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='conv2d_4/Relu:0', description="created by layer 'conv2d_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 32, 32, 128), dtype=tf.float32, name=None), name='conv2d_5/Relu:0', description="created by layer 'conv2d_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 256), dtype=tf.float32, name=None), name='conv2d_6/Relu:0', description="created by layer 'conv2d_6'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 256), dtype=tf.float32, name=None), name='conv2d_7/Relu:0', description="created by layer 'conv2d_7'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='conv2d_8/Relu:0', description="created by layer 'conv2d_8'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 8, 512), dtype=tf.float32, name=None), name='conv2d_9/Relu:0', description="created by layer 'conv2d_9'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 256), dtype=tf.float32, name=None), name='conv2d_transpose/Relu:0', description="created by layer 'conv2d_transpose'")

# %% [markdown]
# Defining metrics

# %%
loss = tf.keras.losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.002)#, momentum=0.7)
metric = tf.keras.metrics.MeanIoU(3, name=None, dtype= None)
model.compile(optimizer= optimizer, loss = loss ,metrics=metric)

# %%
Checkpoint_Model = tf.keras.callbacks.ModelCheckpoint(monitor="val_loss",
                                                      save_best_only=True,    
                                                      save_weights_only=True,
                                                      filepath="./modelcheck")

lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=40, verbose=1)

# %% [markdown]
# Training

# %%
model.fit(x = train_imgs, y = train_masks_categorical, validation_data = (test_imgs,test_masks_categorical), batch_size=15,  epochs=70,  callbacks=[Checkpoint_Model, lr_reduce]) #class_weight=class_weights)
# Out:
# Epoch 1/70
# 93/93 [==============================] - 42s 283ms/step - loss: 0.4087 - mean_io_u: 0.3333 - val_loss: 0.3026 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 2/70
# 93/93 [==============================] - 21s 223ms/step - loss: 0.2736 - mean_io_u: 0.3334 - val_loss: 0.2735 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 3/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.2609 - mean_io_u: 0.3336 - val_loss: 0.2618 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 4/70
# 93/93 [==============================] - 21s 221ms/step - loss: 0.2500 - mean_io_u: 0.3341 - val_loss: 0.2438 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 5/70
# 93/93 [==============================] - 21s 221ms/step - loss: 0.2386 - mean_io_u: 0.3342 - val_loss: 0.2412 - val_mean_io_u: 0.3335 - lr: 0.0020
# Epoch 6/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.2275 - mean_io_u: 0.3343 - val_loss: 0.2330 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 7/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.1946 - mean_io_u: 0.3342 - val_loss: 0.2110 - val_mean_io_u: 0.3338 - lr: 0.0020
# Epoch 8/70
# 93/93 [==============================] - 21s 221ms/step - loss: 0.1637 - mean_io_u: 0.3350 - val_loss: 0.1562 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 9/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.1531 - mean_io_u: 0.3346 - val_loss: 0.3039 - val_mean_io_u: 0.3343 - lr: 0.0020
# Epoch 10/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.1290 - mean_io_u: 0.3371 - val_loss: 0.1696 - val_mean_io_u: 0.3335 - lr: 0.0020
# Epoch 11/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.1182 - mean_io_u: 0.3353 - val_loss: 0.1328 - val_mean_io_u: 0.3335 - lr: 0.0020
# Epoch 12/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.1155 - mean_io_u: 0.3346 - val_loss: 0.1412 - val_mean_io_u: 0.3335 - lr: 0.0020
# Epoch 13/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.1080 - mean_io_u: 0.3352 - val_loss: 0.1281 - val_mean_io_u: 0.3334 - lr: 0.0020
# Epoch 14/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.1074 - mean_io_u: 0.3350 - val_loss: 0.1285 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 15/70
# 93/93 [==============================] - 21s 222ms/step - loss: 0.1094 - mean_io_u: 0.3349 - val_loss: 0.1159 - val_mean_io_u: 0.3334 - lr: 0.0020
# Epoch 16/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.1017 - mean_io_u: 0.3355 - val_loss: 0.1343 - val_mean_io_u: 0.3348 - lr: 0.0020
# Epoch 17/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0980 - mean_io_u: 0.3358 - val_loss: 0.1184 - val_mean_io_u: 0.3341 - lr: 0.0020
# Epoch 18/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0950 - mean_io_u: 0.3360 - val_loss: 0.1290 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 19/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.0896 - mean_io_u: 0.3357 - val_loss: 0.1253 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 20/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0964 - mean_io_u: 0.3370 - val_loss: 0.1525 - val_mean_io_u: 0.3340 - lr: 0.0020
# Epoch 21/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0948 - mean_io_u: 0.3496 - val_loss: 0.1232 - val_mean_io_u: 0.3335 - lr: 0.0020
# Epoch 22/70
# 93/93 [==============================] - 21s 223ms/step - loss: 0.0898 - mean_io_u: 0.3355 - val_loss: 0.1051 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 23/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0877 - mean_io_u: 0.3399 - val_loss: 0.1059 - val_mean_io_u: 0.3374 - lr: 0.0020
# Epoch 24/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.0846 - mean_io_u: 0.3458 - val_loss: 0.1030 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 25/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0853 - mean_io_u: 0.3380 - val_loss: 0.1030 - val_mean_io_u: 0.3334 - lr: 0.0020
# Epoch 26/70
# 93/93 [==============================] - 21s 222ms/step - loss: 0.0808 - mean_io_u: 0.3405 - val_loss: 0.0999 - val_mean_io_u: 0.3334 - lr: 0.0020
# Epoch 27/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0808 - mean_io_u: 0.3391 - val_loss: 0.1190 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 28/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0788 - mean_io_u: 0.3414 - val_loss: 0.1031 - val_mean_io_u: 0.3338 - lr: 0.0020
# Epoch 29/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0806 - mean_io_u: 0.3382 - val_loss: 0.1025 - val_mean_io_u: 0.3342 - lr: 0.0020
# Epoch 30/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.0812 - mean_io_u: 0.3395 - val_loss: 0.1027 - val_mean_io_u: 0.3334 - lr: 0.0020
# Epoch 31/70
# 93/93 [==============================] - 21s 222ms/step - loss: 0.0767 - mean_io_u: 0.3434 - val_loss: 0.0999 - val_mean_io_u: 0.3354 - lr: 0.0020
# Epoch 32/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0770 - mean_io_u: 0.3395 - val_loss: 0.1121 - val_mean_io_u: 0.3335 - lr: 0.0020
# Epoch 33/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.0779 - mean_io_u: 0.3409 - val_loss: 0.1079 - val_mean_io_u: 0.3374 - lr: 0.0020
# Epoch 34/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0753 - mean_io_u: 0.3421 - val_loss: 0.1013 - val_mean_io_u: 0.3341 - lr: 0.0020
# Epoch 35/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0766 - mean_io_u: 0.3458 - val_loss: 0.1050 - val_mean_io_u: 0.3352 - lr: 0.0020
# Epoch 36/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0742 - mean_io_u: 0.3422 - val_loss: 0.1062 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 37/70
# 93/93 [==============================] - 20s 219ms/step - loss: 0.0755 - mean_io_u: 0.3452 - val_loss: 0.0965 - val_mean_io_u: 0.3399 - lr: 0.0020
# Epoch 38/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0776 - mean_io_u: 0.3443 - val_loss: 0.0968 - val_mean_io_u: 0.3333 - lr: 0.0020
# Epoch 39/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0740 - mean_io_u: 0.3443 - val_loss: 0.1231 - val_mean_io_u: 0.3346 - lr: 0.0020
# Epoch 40/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0750 - mean_io_u: 0.3424 - val_loss: 0.1292 - val_mean_io_u: 0.3355 - lr: 0.0020
# Epoch 41/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0765 - mean_io_u: 0.3465 - val_loss: 0.1019 - val_mean_io_u: 0.3345 - lr: 0.0020
# Epoch 42/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0702 - mean_io_u: 0.3417 - val_loss: 0.1029 - val_mean_io_u: 0.3336 - lr: 0.0020
# Epoch 43/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0710 - mean_io_u: 0.3403 - val_loss: 0.1000 - val_mean_io_u: 0.3346 - lr: 0.0020
# Epoch 44/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0731 - mean_io_u: 0.3483 - val_loss: 0.0988 - val_mean_io_u: 0.3341 - lr: 0.0020
# Epoch 45/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0750 - mean_io_u: 0.3419 - val_loss: 0.1035 - val_mean_io_u: 0.3341 - lr: 0.0020
# Epoch 46/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0701 - mean_io_u: 0.3484 - val_loss: 0.1343 - val_mean_io_u: 0.3380 - lr: 0.0020
# Epoch 47/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0696 - mean_io_u: 0.3450 - val_loss: 0.1137 - val_mean_io_u: 0.3413 - lr: 0.0020
# Epoch 48/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0682 - mean_io_u: 0.3484 - val_loss: 0.1154 - val_mean_io_u: 0.3345 - lr: 0.0020
# Epoch 49/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0695 - mean_io_u: 0.3481 - val_loss: 0.0998 - val_mean_io_u: 0.3339 - lr: 0.0020
# Epoch 50/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0675 - mean_io_u: 0.3430 - val_loss: 0.1061 - val_mean_io_u: 0.3350 - lr: 0.0020
# Epoch 51/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0678 - mean_io_u: 0.3447 - val_loss: 0.1001 - val_mean_io_u: 0.3338 - lr: 0.0020
# Epoch 52/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0671 - mean_io_u: 0.3515 - val_loss: 0.1068 - val_mean_io_u: 0.3334 - lr: 0.0020
# Epoch 53/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0696 - mean_io_u: 0.3507 - val_loss: 0.1013 - val_mean_io_u: 0.3341 - lr: 0.0020
# Epoch 54/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0661 - mean_io_u: 0.3491 - val_loss: 0.1150 - val_mean_io_u: 0.3337 - lr: 0.0020
# Epoch 55/70
# 93/93 [==============================] - 21s 221ms/step - loss: 0.0693 - mean_io_u: 0.3542 - val_loss: 0.0960 - val_mean_io_u: 0.3352 - lr: 0.0020
# Epoch 56/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0671 - mean_io_u: 0.3490 - val_loss: 0.1009 - val_mean_io_u: 0.3345 - lr: 0.0020
# Epoch 57/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0696 - mean_io_u: 0.3532 - val_loss: 0.1146 - val_mean_io_u: 0.3343 - lr: 0.0020
# Epoch 58/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0745 - mean_io_u: 0.3511 - val_loss: 0.0996 - val_mean_io_u: 0.3374 - lr: 0.0020
# Epoch 59/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0709 - mean_io_u: 0.3408 - val_loss: 0.0984 - val_mean_io_u: 0.3389 - lr: 0.0020
# Epoch 60/70
# 93/93 [==============================] - 20s 214ms/step - loss: 0.0666 - mean_io_u: 0.3437 - val_loss: 0.1083 - val_mean_io_u: 0.3373 - lr: 0.0020
# Epoch 61/70
# 93/93 [==============================] - 20s 216ms/step - loss: 0.0628 - mean_io_u: 0.3561 - val_loss: 0.1104 - val_mean_io_u: 0.3364 - lr: 0.0020
# Epoch 62/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0658 - mean_io_u: 0.3519 - val_loss: 0.1013 - val_mean_io_u: 0.3374 - lr: 0.0020
# Epoch 63/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0682 - mean_io_u: 0.3519 - val_loss: 0.1027 - val_mean_io_u: 0.3356 - lr: 0.0020
# Epoch 64/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0634 - mean_io_u: 0.3490 - val_loss: 0.0966 - val_mean_io_u: 0.3342 - lr: 0.0020
# Epoch 65/70
# 93/93 [==============================] - 20s 217ms/step - loss: 0.0645 - mean_io_u: 0.3474 - val_loss: 0.1028 - val_mean_io_u: 0.3345 - lr: 0.0020
# Epoch 66/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0633 - mean_io_u: 0.3578 - val_loss: 0.1061 - val_mean_io_u: 0.3339 - lr: 0.0020
# Epoch 67/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0625 - mean_io_u: 0.3508 - val_loss: 0.0971 - val_mean_io_u: 0.3465 - lr: 0.0020
# Epoch 68/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0622 - mean_io_u: 0.3685 - val_loss: 0.1079 - val_mean_io_u: 0.3356 - lr: 0.0020
# Epoch 69/70
# 93/93 [==============================] - 20s 218ms/step - loss: 0.0626 - mean_io_u: 0.3558 - val_loss: 0.1022 - val_mean_io_u: 0.3339 - lr: 0.0020
# Epoch 70/70
# 93/93 [==============================] - 20s 215ms/step - loss: 0.0642 - mean_io_u: 0.3694 - val_loss: 0.1005 - val_mean_io_u: 0.3352 - lr: 0.0020

# %% [markdown]
# Prediction visualization

# %%
predicao = model.predict(test_imgs[:50])
for i in range(50):
  
  pred = (predicao[i])
  fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize = (25,25))

  pred0 = tf.where(pred>0.5,233,0)
  org = test_masks[i][:,:,0]
  img = test_imgs[i][:,:,0]
  ax1.imshow(pred0)
  ax1.set_title('Prediction ')

  ax2.imshow(org)#, cmap = 'binary_r')
  ax2.set_title('Original mask')

  ax3.imshow(img)
  ax3.set_title('Original Image')
  plt.show()
